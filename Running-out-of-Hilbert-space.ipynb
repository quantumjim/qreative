# %%
from creative import *

# %%
length = 30
num

w = walker(length,5,'00000')

for steps in range(length):

    stats = w.get_step(steps)

    sorted_strings = sorted(stats,key=stats.get)[::-1]
    sorted_probs = sorted(stats.values())[::-1]

    for string,prob in zip(sorted_strings,sorted_probs):
        print(string,prob)
        for n
        
    print('\n')
# Out:
# 00000 1.0
#
#
# 00000 1.0
#
#
# 00000 1.0
#
#
# 00000 0.869140625
# 00100 0.130859375
#
#
# 00000 0.720703125
# 00100 0.130859375
# 01000 0.123046875
# 01100 0.025390625
#
#
# 00000 0.7197265625
# 01000 0.130859375
# 00100 0.130859375
# 01100 0.0185546875
#
#
# 00000 0.6357421875
# 01000 0.20703125
# 00100 0.123046875
# 01100 0.0341796875
#
#
# 00000 0.55078125
# 01000 0.1865234375
# 00100 0.0966796875
# 10000 0.080078125
# 11000 0.0341796875
# 01100 0.03125
# 10100 0.017578125
# 11100 0.0029296875
#
#
# 00000 0.5634765625
# 01000 0.1826171875
# 10000 0.0908203125
# 00100 0.0830078125
# 01100 0.0322265625
# 11000 0.0244140625
# 10100 0.017578125
# 11100 0.005859375
#
#
# 00000 0.474609375
# 01000 0.15234375
# 10000 0.083984375
# 00100 0.080078125
# 00001 0.056640625
# 01100 0.0390625
# 01001 0.0283203125
# 11000 0.0244140625
# 10100 0.0166015625
# 10001 0.0146484375
# 00101 0.013671875
# 11100 0.005859375
# 10101 0.00390625
# 11001 0.0029296875
# 01101 0.001953125
# ...
